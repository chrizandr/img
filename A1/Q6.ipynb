# %% [markdown]
# ### Report Q6
#
# The code for Q6 can be found in Q5.py file. We will import the functions defined in the file to demonstrate usbaility and give results for different questions.
#
#
# #### Here is the implementation for Bit Quantization:

# %%
# Import necessary functions
from skimage import img_as_ubyte
from skimage.io import imread

import matplotlib
# %matplotlib inline

from Q6 import BitQuantized, showImages, plot_Quantized

# %%
# Read image and convert to 8bit grayscale
img = imread("A1_resources/puppy.jpg", as_gray=True)
img = img_as_ubyte(img)

# Do histogram equilization
result = BitQuantized(img, 3)

# See the results
showImages(img, result)
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %% [markdown]
# #### For an 8bit image, the valid values of k would be [1, 7]. In general for an n-bit image, the valid values of k would be [1, n-1].

# %%
result = BitQuantized(img, 10)   # Wrong value of k gives an error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a498f602c59e> in <module>()
# ----> 1 result = BitQuantized(img, 10)   # Wrong value of k gives an error
#
# ~/img/A1/Q6.py in BitQuantized(img, k)
#      11     quant = 2**k - 1
#      12     if quant > 255 or quant < 1:
# ---> 13         raise ValueError("Invalid value for k")
#      14
#      15     m, n = img.shape
#
# ValueError: Invalid value for k

# %%
plot_Quantized(img)
# Out:
# 1 bit Quantized image
# 2 bit Quantized image
# 3 bit Quantized image
# 4 bit Quantized image
# 5 bit Quantized image
# 6 bit Quantized image
# 7 bit Quantized image
