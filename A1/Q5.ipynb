# %% [markdown]
# ### Report Q5
#
# The code for Q5 can be found in Q5.py file. We will import the functions defined in the file to demonstrate usbaility and give results for different questions.
#
#
# #### Here is the implementation fo histogram equilization:

# %%
# Import necessary functions
from skimage import img_as_ubyte
from skimage.io import imread

import matplotlib
# %matplotlib inline

from Q5 import HistogramEq
from Q5 import showImages

# %% [markdown]
# We then do histogram equilization

# %%
# Read image and convert to 8bit grayscale
img = imread("A1_resources/hist_equal.jpg", as_gray=True)
img = img_as_ubyte(img)

# Do histogram equilization
result = HistogramEq(img)

# See the results
showImages(img, result)
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
# Read image and convert to 8bit grayscale
img = imread("A1_resources/hist_equal2.jpg", as_gray=True)
img = img_as_ubyte(img)

# Do histogram equilization
result = HistogramEq(img)

# See the results
showImages(img, result)
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %% [markdown]
# #### Here is the implementation fo local histogram equilization. (Code will take time to run)
#
# 5x5 window is used everywhere as this was found to give best results out of 3, 5, 7.

# %%
from Q5 import local_HistogramEq

# %%
# Read image and convert to 8bit grayscale
img = imread("A1_resources/hist_equal.jpg", as_gray=True)
img = img_as_ubyte(img)

# Do histogram equilization
result = local_HistogramEq(img, 5)

# See the results
showImages(img, result)
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
# Read image and convert to 8bit grayscale
img = imread("A1_resources/hist_equal2.jpg", as_gray=True)
img = img_as_ubyte(img)

# Do histogram equilization
result = local_HistogramEq(img, 5)

# See the results
showImages(img, result)
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %% [markdown]
# #### Here is the implementation of Histogram matching

# %%
# Import extra functions
from Q5 import hist_match
from Q5 import showImages2

src = imread("A1_resources/hist-match-1.jpg", as_gray=True)
src = img_as_ubyte(src)

trgt = imread("A1_resources/hist-match-2.jpg", as_gray=True)
trgt = img_as_ubyte(trgt)

result = hist_match(src, trgt)
showImages2(src, trgt, result)
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
